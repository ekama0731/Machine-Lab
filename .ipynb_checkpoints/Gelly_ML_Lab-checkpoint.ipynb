# %%
import pandas as pd

path_to_file = "./../data/Orders.csv"
data = pd.read_csv(path_to_file)
print(data.shape)
data.head()
# Out:
# (51290, 24)
#    Row.ID                  Order.ID Order.Date Ship.Date     Ship.Mode  \
# 0   40098  CA-2014-AB10015140-41954   11/11/14  11/13/14   First Class
# 1   26341    IN-2014-JR162107-41675     2/5/14    2/7/14  Second Class
# 2   25330    IN-2014-CR127307-41929   10/17/14  10/18/14   First Class
# 3   13524   ES-2014-KM1637548-41667    1/28/14   1/30/14   First Class
# 4   47221   SG-2014-RH9495111-41948    11/5/14   11/6/14      Same Day
#
#     Customer.ID     Customer.Name      Segment  Postal.Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#         ...         Product.ID    Category Sub.Category  \
# 0       ...        TEC-PH-5816  Technology       Phones
# 1       ...        FUR-CH-5379   Furniture       Chairs
# 2       ...        TEC-PH-5356  Technology       Phones
# 3       ...        TEC-PH-5267  Technology       Phones
# 4       ...        TEC-CO-6011  Technology      Copiers
#
#                                 Product.Name      Sales Quantity Discount  \
# 0                           Samsung Convoy 3    $221.98        2      0.0
# 1  Novimex Executive Leather Armchair, Black  $3,709.40        9      0.1
# 2          Nokia Smart Phone, with Caller ID  $5,175.17        9      0.1
# 3             Motorola Smart Phone, Cordless  $2,892.51        5      0.1
# 4             Sharp Wireless Fax, High-Speed  $2,832.96        8      0.0
#
#      Profit Shipping.Cost  Order.Priority
# 0    $62.15         40.77            High
# 1  -$288.77        923.63        Critical
# 2   $919.97        915.49          Medium
# 3   -$96.54        910.16          Medium
# 4   $311.52        903.04        Critical
#
# [5 rows x 24 columns]

# %%
import re
def clean_prof_sales(x):
    empty_list = []
    for i in x:
        m = re.search('\d+\.\d+', i)
        empty_list.append(float(m.group()))
    return empty_list

# %%
# convert sales and profit to numeric
data.Sales = clean_prof_sales(data.Sales)
data.Profit = clean_prof_sales(data.Profit)

# %%
# order.date to datetime
from datetime import datetime
data['Order.Date']= [datetime.strptime(i,'%m/%d/%y') for i in data['Order.Date']]

# %%
# create month column
list = []
for i in data['Order.Date']:
    list.append(i.month)

# %%
data['Order.Month'] = list

# %%
orderXmonth = data.groupby(data['Order.Month']).sum()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# plot orders per month
plt.scatter(y = orderXmonth['Quantity'], x= orderXmonth.index)

# %%
orderXcat = data.groupby(['Order.Month','Category']).sum()

# %%
orderXcat = orderXcat.reset_index(drop=False)

# %%
furn = orderXcat[orderXcat.Category == "Furniture"]

# %%
OS = orderXcat[orderXcat.Category == "Office Supplies"]
Tech = orderXcat[orderXcat.Category == "Technology"]

# %%
plt.scatter(y = furn['Quantity'], x= furn['Order.Month'])
plt.scatter(y = OS['Quantity'], x= OS['Order.Month'])
plt.scatter(y = Tech['Quantity'], x= Tech['Order.Month'])

# %%
# - Your manager required you to give a brief report (**Plots + Interpretations**) on returned orders.

# 	1. How much profit did we lose due to returns each year?


# 	2. How many customer returned more than once? more than 5 times?


# 	3. Which regions are more likely to return orders?


# 	4. Which categories (sub-categories) of products are more likely to be returned?

# - ***Hint:*** Merge the **Returns** dataframe with the **Orders** dataframe using `Order.ID`.

# %%
path_to_file = "./../Data/Returns.csv"
returns = pd.read_csv(path_to_file)

# %%
returns=returns.rename(columns = {'Order ID':'Order.ID'})

# %%
returns.head()
# Out:
#   Returned                  Order.ID        Region
# 0      Yes  CA-2012-SA20830140-41210    Central US
# 1      Yes  IN-2012-PB19210127-41259  Eastern Asia
# 2      Yes  CA-2012-SC20095140-41174    Central US
# 3      Yes    IN-2015-JH158207-42140       Oceania
# 4      Yes    IN-2014-LC168857-41747       Oceania

# %%
#change west and east Canada to Canada in returns

mask = returns.Region == "Eastern Canada"
column_name = 'Region'
returns.loc[mask, column_name] = "Canada"

mask = returns.Region == "Western Canada"
column_name = 'Region'
returns.loc[mask, column_name] = "Canada"

# %%
returns.Region.unique()
# Out:
# array(['Central US', 'Eastern Asia', 'Oceania', 'Western Europe',
#        'Southern Europe', 'Western Asia', 'Southern US',
#        'Southern Africa', 'Eastern US', 'Eastern Europe',
#        'Southeastern Asia', 'Western US', 'Southern Asia',
#        'Northern Europe', 'Canada', 'Central America', 'South America',
#        'North Africa', 'Caribbean', 'Central Africa', 'Western Africa',
#        'Eastern Africa', 'Central Asia'], dtype=object)

# %%
merge = pd.merge(data, returns,  how='left', on = 'Order.ID')

# %%
returned = merge[merge.Returned.notnull()]

# %%
list1 = []
for i in returned['Order.Date']:
    list1.append(i.year)

# %%
returned['Year'] = list1
# Out:
# /Users/bennettgelly/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
retXyear = returned.groupby(['Year']).sum()

# %%
# profit lost per year from returns
retXyear
# Out:
#         Row.ID  Postal.Code      Sales  Quantity  Discount    Profit  \
# Year
# 2012  11019108    5512777.0   74935.81      1457    66.968  23022.34
# 2013  10678896    5025481.0   67575.21      1508    66.860  22695.95
# 2014  15493169    7994617.0  100737.41      2096    81.714  31389.49
# 2015  19394127    7911427.0  129683.98      2614   110.986  46928.17
#
#       Shipping.Cost  Order.Month
# Year
# 2012      12636.185         3390
# 2013      11137.672         3353
# 2014      15856.426         4418
# 2015      21212.313         5888

# %%
import collections

counter=collections.Counter(retCust)
#print(counter)

over_five = dict((k, v) for k, v in counter.items() if v > 5)
over_one = dict((k, v) for k, v in counter.items() if v > 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-15baeab308c9> in <module>()
#       1 import collections
#       2
# ----> 3 counter=collections.Counter(retCust)
#       4 #print(counter)
#       5
#
# NameError: name 'retCust' is not defined

# %%
# customers that returned over five times
len(over_five)

# %%
# customers that returned more than once
len(over_one)

# %%
# returns per region
full_regionRet = data.groupby(['Region']).size()

# %%
# orders per region
ret_regionRet = returns.groupby(['Region']).size()

# %%
full_regionRet = pd.DataFrame(full_regionRet).reset_index()
ret_regionRet = pd.DataFrame(ret_regionRet).reset_index()

# %%
# rename cols before merge
ret_regionRet=ret_regionRet.rename(columns = {0:'returns'})
full_regionRet=full_regionRet.rename(columns = {0:'returnsFull'})

# %%
# merge
full = pd.merge(full_regionRet, ret_regionRet, how = 'left', on = 'Region')

# %%
# calc percent return column
full['percRet'] = full.returns / full.returnsFull *100

# %%
# sort perc return column
sort = full.sort_values(['percRet'], ascending=[False])
#sort
# Southern U.S., Southern EU, Eastern US, South Africa, Western US most likely to return

# %%
# plot
x = sort[['percRet', 'Region']]
y = pd.DataFrame.drop_duplicates(x)
y =y.set_index('Region')
y.sort_values('percRet', ascending=False)[['percRet']].plot.bar(stacked=True, rot=90)

# %%
# returns per sub category
full_catRet = data.groupby(['Sub.Category']).size()

# %%
# orders per sub category
ret_catRet = returned.groupby(['Sub.Category']).size()

# %%
full_catRet = pd.DataFrame(full_catRet).reset_index()
ret_catRet = pd.DataFrame(ret_catRet).reset_index()

# %%
# rename cols before merge
ret_catRet=ret_catRet.rename(columns = {0:'returns'})
full_catRet=full_catRet.rename(columns = {0:'ordersFull'})

# %%
# merge
full1 = pd.merge(full_catRet, ret_catRet, how = 'left', on = 'Sub.Category')

# %%
# calc percent return column
full1['percRet'] = full1.returns / full1.ordersFull *100

# %%
# plot
x1 = full1[['percRet', 'Sub.Category']]
y1 = pd.DataFrame.drop_duplicates(x1)
y1 =y1.set_index('Sub.Category')
y1.sort_values('percRet', ascending=False)[['percRet']].plot.bar(stacked=True, rot=90)

# %%
# Labels, Tables, Accessories returned the most. Appliances and fasteners the least

# %%
# imbalanced dataset, less than 5% have been returned. So can't use accuracy to eval model
# what method should we use to eval model in this data set -createdatapartition, binary classification
# each team member pick one algorithm - which should we recommend or submit?
# AUC, log loss, type 1 error, type 2 error - all metrics for error. Which types of error do we care about the most?
# regression - highest accuracy. Classificiation - type 1 false positive. 
# start with feature engineering
# yes returned or no

# %%
# mask = merge['Returned'].isnull()
# column_name = 'Returned'
# merge.loc[mask, column_name] = "test"

# mask = merge.Returned == merge.Returned.notnull()
# column_name = 'Returned'
# returns.loc[mask, column_name] = 1

# %%
merge
# Out:
#        Row.ID                  Order.ID Order.Date Ship.Date       Ship.Mode  \
# 0       40098  CA-2014-AB10015140-41954 2014-11-11  11/13/14     First Class
# 1       26341    IN-2014-JR162107-41675 2014-02-05    2/7/14    Second Class
# 2       25330    IN-2014-CR127307-41929 2014-10-17  10/18/14     First Class
# 3       13524   ES-2014-KM1637548-41667 2014-01-28   1/30/14     First Class
# 4       47221   SG-2014-RH9495111-41948 2014-11-05   11/6/14        Same Day
# 5       22732    IN-2014-JM156557-41818 2014-06-28    7/1/14    Second Class
# 6       30570   IN-2012-TS2134092-41219 2012-11-06   11/8/12     First Class
# 7       31192   IN-2013-MB1808592-41378 2013-04-14   4/18/13  Standard Class
# 8       40099  CA-2014-AB10015140-41954 2014-11-11  11/13/14     First Class
# 9       36258  CA-2012-AB10015140-40974 2012-03-06    3/7/12     First Class
# 10      36259  CA-2012-AB10015140-40974 2012-03-06    3/7/12     First Class
# 11      28879    ID-2013-AJ107801-41383 2013-04-19   4/22/13     First Class
# 12      45794   SA-2012-MM7260110-41269 2012-12-26  12/28/12    Second Class
# 13       4132   MX-2013-VF2171518-41591 2013-11-13  11/13/13        Same Day
# 14      27704   IN-2014-PF1912027-41796 2014-06-06    6/8/14    Second Class
# 15      13779   ES-2015-BP1118545-42216 2015-07-31    8/3/15    Second Class
# 16      39519  CA-2012-AB10015140-40958 2012-02-19   2/25/12  Standard Class
# 17      12069   ES-2015-PJ1883564-42255 2015-09-08   9/14/15  Standard Class
# 18      22096    IN-2015-JS156857-42035 2015-01-31    2/1/15     First Class
# 19      49463   TZ-2015-RH9555129-42343 2015-12-05   12/7/15    Second Class
# 20      46630    PL-2013-AB600103-41494 2013-08-08   8/10/13     First Class
# 21      36260  CA-2012-AB10015140-40974 2012-03-06    3/7/12     First Class
# 22      21586   IN-2012-JK1532527-41030 2012-05-01    5/2/12     First Class
# 23      13528  ES-2014-LB16795139-41697 2014-02-27    3/1/14    Second Class
# 24       1570   US-2015-NP1832582-42216 2015-07-31    8/1/15     First Class
# 25       3484   MX-2015-VD2167039-42252 2015-09-05    9/8/15     First Class
# 26      30191  IN-2012-PB19210127-41259 2012-12-16  12/19/12     First Class
# 27      11645   ES-2012-EB1411048-40981 2012-03-13   3/16/12    Second Class
# 28      38460  CA-2012-AH10030140-41020 2012-04-21   4/23/12    Second Class
# 29      22999   IN-2013-BP1123058-41329 2013-02-24   2/24/13        Same Day
# ...       ...                       ...        ...       ...             ...
# 51260   35398  US-2015-ZC21910140-42175 2015-06-20   6/24/15  Standard Class
# 51261   35111  CA-2014-ZD21925140-41829 2014-07-09    7/9/14        Same Day
# 51262   31316  CA-2012-ZD21925140-41147 2012-08-26   8/31/12    Second Class
# 51263    6367   MX-2012-BP1123082-41264 2012-12-21  12/25/12  Standard Class
# 51264   22589    IN-2015-AO108107-42333 2015-11-25  11/30/15  Standard Class
# 51265   37195  CA-2014-ZD21925140-41733 2014-04-04   4/10/14  Standard Class
# 51266   27081  ID-2013-EK13795102-41496 2013-08-10   8/11/13     First Class
# 51267   39638  CA-2015-ZD21925140-42167 2015-06-12   6/15/15     First Class
# 51268   47274   SA-2015-JW6075110-42103 2015-04-09   4/13/15  Standard Class
# 51269   15975  ES-2012-MM18055139-41038 2012-05-09   5/13/12  Standard Class
# 51270   13800   ES-2015-NM1852045-42221 2015-08-05   8/11/15  Standard Class
# 51271   37194  CA-2014-ZD21925140-41733 2014-04-04   4/10/14  Standard Class
# 51272    5465   MX-2015-AA1048031-42111 2015-04-17   4/20/15    Second Class
# 51273    9309   MX-2015-SL2015518-42258 2015-09-11   9/12/15     First Class
# 51274    5596   MX-2014-SS2041082-41912 2014-09-30   10/2/14    Second Class
# 51275   46231    ZA-2012-AS285147-40988 2012-03-20   3/25/12  Standard Class
# 51276   31317  CA-2012-ZD21925140-41147 2012-08-26   8/31/12    Second Class
# 51277   46582   TU-2015-KF6285134-42337 2015-11-29  11/30/15     First Class
# 51278   10410   ES-2012-LR1703548-41245 2012-12-02   12/2/12        Same Day
# 51279   43818    NI-2012-PO886595-41159 2012-09-07    9/9/12    Second Class
# 51280   35112  CA-2014-ZD21925140-41829 2014-07-09    7/9/14        Same Day
# 51281    6039   MX-2015-HG1502518-42164 2015-06-09   6/11/15     First Class
# 51282   24175    IN-2015-DB132707-42221 2015-08-05   8/10/15  Standard Class
# 51283   24105   IN-2015-KH1633058-42154 2015-05-30   5/30/15        Same Day
# 51284    9922   MX-2013-KM1637593-41636 2013-12-28  12/31/13     First Class
# 51285   29002   IN-2015-KE1642066-42174 2015-06-19   6/19/15        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2014-05-06   5/10/14  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2012-08-26   8/31/12    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2013-02-17   2/21/13  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2013-05-22   5/26/13    Second Class
#
#         Customer.ID       Customer.Name      Segment  Postal.Code  \
# 0      AB-100151402       Aaron Bergman     Consumer      73120.0
# 1         JR-162107       Justin Ritter    Corporate          NaN
# 2         CR-127307        Craig Reiter     Consumer          NaN
# 3        KM-1637548    Katherine Murray  Home Office          NaN
# 4        RH-9495111         Rick Hansen     Consumer          NaN
# 5         JM-156557         Jim Mitchum    Corporate          NaN
# 6        TS-2134092       Toby Swindell     Consumer          NaN
# 7        MB-1808592          Mick Brown     Consumer          NaN
# 8      AB-100151402       Aaron Bergman     Consumer      73120.0
# 9      AB-100151404       Aaron Bergman     Consumer      98103.0
# 10     AB-100151404       Aaron Bergman     Consumer      98103.0
# 11        AJ-107801      Anthony Jacobs    Corporate          NaN
# 12       MM-7260110     Magdelene Morse     Consumer          NaN
# 13       VF-2171518      Vicky Freymann  Home Office          NaN
# 14       PF-1912027        Peter Fuller     Consumer          NaN
# 15       BP-1118545        Ben Peterman    Corporate          NaN
# 16     AB-100151402       Aaron Bergman     Consumer      76017.0
# 17       PJ-1883564       Patrick Jones    Corporate          NaN
# 18        JS-156857            Jim Sink    Corporate          NaN
# 19       RH-9555129     Ritsa Hightower     Consumer          NaN
# 20        AB-600103           Ann Blume    Corporate          NaN
# 21     AB-100151404       Aaron Bergman     Consumer      98103.0
# 22       JK-1532527   Jason Klamczynski    Corporate          NaN
# 23      LB-16795139      Laurel Beltran  Home Office          NaN
# 24       NP-1832582        Naresj Patel     Consumer          NaN
# 25       VD-2167039   Valerie Dominguez     Consumer          NaN
# 26      PB-19210127      Phillip Breyer    Corporate          NaN
# 27       EB-1411048      Eugene Barchas     Consumer          NaN
# 28     AH-100301406       Aaron Hawkins    Corporate      12180.0
# 29       BP-1123058  Benjamin Patterson     Consumer          NaN
# ...             ...                 ...          ...          ...
# 51260  ZC-219101402    Zuschuss Carroll     Consumer      77095.0
# 51261  ZD-219251408  Zuschuss Donatelli     Consumer      32216.0
# 51262  ZD-219251404  Zuschuss Donatelli     Consumer      94109.0
# 51263    BP-1123082  Benjamin Patterson     Consumer          NaN
# 51264     AO-108107   Anthony O'Donnell    Corporate          NaN
# 51265  ZD-219251402  Zuschuss Donatelli     Consumer      47374.0
# 51266   EK-13795102       Eileen Kiefer  Home Office          NaN
# 51267  ZD-219251404  Zuschuss Donatelli     Consumer      90036.0
# 51268    JW-6075110          Julia West     Consumer          NaN
# 51269   MM-18055139      Michelle Moray     Consumer          NaN
# 51270    NM-1852045        Neoma Murray     Consumer          NaN
# 51271  ZD-219251402  Zuschuss Donatelli     Consumer      47374.0
# 51272    AA-1048031        Andrew Allen     Consumer          NaN
# 51273    SL-2015518      Sara Luxemburg  Home Office          NaN
# 51274    SS-2041082     Shahid Shariari     Consumer          NaN
# 51275     AS-285147    Alejandro Savely    Corporate          NaN
# 51276  ZD-219251404  Zuschuss Donatelli     Consumer      94109.0
# 51277    KF-6285134      Karen Ferguson  Home Office          NaN
# 51278    LR-1703548           Lisa Ryan    Corporate          NaN
# 51279     PO-886595   Patrick O'Donnell     Consumer          NaN
# 51280  ZD-219251408  Zuschuss Donatelli     Consumer      32216.0
# 51281    HG-1502518       Hunter Glantz     Consumer          NaN
# 51282     DB-132707   Deborah Brumfield  Home Office          NaN
# 51283    KH-1633058     Katharine Harms    Corporate          NaN
# 51284    KM-1637593    Katherine Murray  Home Office          NaN
# 51285    KE-1642066     Katrina Edelman    Corporate          NaN
# 51286  ZD-219251408  Zuschuss Donatelli     Consumer      37421.0
# 51287  ZD-219251404  Zuschuss Donatelli     Consumer      94109.0
# 51288    RB-1979518          Ross Baird  Home Office          NaN
# 51289    MC-1810093       Mick Crebagga     Consumer          NaN
#
#                         City      ...       \
# 0              Oklahoma City      ...
# 1                 Wollongong      ...
# 2                   Brisbane      ...
# 3                     Berlin      ...
# 4                      Dakar      ...
# 5                     Sydney      ...
# 6                    Porirua      ...
# 7                   Hamilton      ...
# 8              Oklahoma City      ...
# 9                    Seattle      ...
# 10                   Seattle      ...
# 11                     Kabul      ...
# 12                     Jizan      ...
# 13                    Toledo      ...
# 14                Mudanjiang      ...
# 15                     Paris      ...
# 16                 Arlington      ...
# 17                     Prato      ...
# 18                Townsville      ...
# 19                    Uvinza      ...
# 20                     Bytom      ...
# 21                   Seattle      ...
# 22                    Suzhou      ...
# 23                 Edinburgh      ...
# 24                    Juárez      ...
# 25                 Soyapango      ...
# 26                    Taipei      ...
# 27                   Leipzig      ...
# 28                      Troy      ...
# 29                     Surat      ...
# ...                      ...      ...
# 51260                Houston      ...
# 51261           Jacksonville      ...
# 51262          San Francisco      ...
# 51263                 Toluca      ...
# 51264                  Perth      ...
# 51265               Richmond      ...
# 51266                  Pasig      ...
# 51267            Los Angeles      ...
# 51268                 Riyadh      ...
# 51269                 Dudley      ...
# 51270               Chartres      ...
# 51271               Richmond      ...
# 51272  San José de las Lajas      ...
# 51273             Vespasiano      ...
# 51274               Acayucan      ...
# 51275                 Harare      ...
# 51276          San Francisco      ...
# 51277                 Midyat      ...
# 51278                Hamburg      ...
# 51279                  Lagos      ...
# 51280           Jacksonville      ...
# 51281      Bragança Paulista      ...
# 51282             Townsville      ...
# 51283                Lucknow      ...
# 51284                Managua      ...
# 51285                   Kure      ...
# 51286            Chattanooga      ...
# 51287          San Francisco      ...
# 51288               Valinhos      ...
# 51289               Tipitapa      ...
#
#                                             Product.Name   Sales Quantity  \
# 0                                       Samsung Convoy 3  221.98        2
# 1              Novimex Executive Leather Armchair, Black  709.40        9
# 2                      Nokia Smart Phone, with Caller ID  175.17        9
# 3                         Motorola Smart Phone, Cordless  892.51        5
# 4                         Sharp Wireless Fax, High-Speed  832.96        8
# 5                    Samsung Smart Phone, with Caller ID  862.68        5
# 6         Novimex Executive Leather Armchair, Adjustable  822.08        4
# 7           Chromcraft Conference Table, Fully Assembled  244.84        6
# 8      Sauder Facets Collection Library, Sky Alder Fi...  341.96        2
# 9             Global Push Button Manager's Chair, Indigo   48.71        1
# 10                                            Newell 330   17.94        3
# 11               Bevis Conference Table, Fully Assembled  626.15        5
# 12                     Cisco Smart Phone, with Caller ID  616.96        4
# 13     Harbour Creations Executive Leather Armchair, ...  221.80        7
# 14                           KitchenAid Microwave, White  701.52       12
# 15                            Breville Refrigerator, Red  869.59        4
# 16                                    Akro Stacking Bins   12.62        2
# 17                                     Hoover Stove, Red  958.58       14
# 18                       Brother Fax Machine, High-Speed  565.59        9
# 19                               KitchenAid Stove, White  409.74        6
# 20               Hon Computer Table, with Bottom Storage  977.72        4
# 21               Carina 42"Hx23 3/4"W Media Storage Unit  242.94        3
# 22               SAFCO Executive Leather Armchair, Black  754.00        6
# 23                        KitchenAid Refrigerator, Black  273.70       10
# 24                       Motorola Smart Phone, Full Size  713.84        4
# 25                   Hon Computer Table, Fully Assembled  106.50        8
# 26           Lesro Conference Table, with Bottom Storage  715.16        2
# 27                                     Hoover Stove, Red   69.74        6
# 28                                               Staples  247.84        8
# 29           Office Star Executive Leather Armchair, Red  878.72        4
# ...                                                  ...     ...      ...
# 51260  Hoover Replacement Belt for Commercial Guardsm...    0.44        1
# 51261           Jabra SPEAK 410 Multidevice Speakerphone  823.96        5
# 51262                            Cisco SPA 501G IP Phone  213.48        3
# 51263                       Acco Binder Covers, Recycled   36.48        4
# 51264                GlobeWeis Manila Envelope, Recycled   47.14        2
# 51265     Plantronics Voyager Pro HD - Bluetooth Headset  259.96        4
# 51266        Enermax Computer Printout Paper, Multicolor   49.30        3
# 51267  Kensington 6 Outlet Guardian Standard Surge Pr...   61.44        3
# 51268              Cardinal Hole Reinforcements, Economy    5.34        1
# 51269              Stanley Pencil Sharpener, Water Color  200.40        8
# 51270             Avery File Folder Labels, Alphabetical   17.88        2
# 51271                     Seth Thomas 13 1/2" Wall Clock   71.12        4
# 51272                            Boston Pens, Easy-Erase   19.32        2
# 51273                Novimex Shipping Labels, Adjustable    5.92        1
# 51274                           Ibico Index Tab, Economy   41.64        6
# 51275                   Sanford Highlighters, Easy-Erase    9.61        2
# 51276        Wilson Jones Hanging View Binder, White, 1"   22.72        4
# 51277                                  Boston Pens, Blue   34.13        6
# 51278                      Acco Binding Machine, Durable   52.59        1
# 51279                  Stanley Highlighters, Water Color    5.36        1
# 51280                                         Xerox 1921   15.98        2
# 51281                Green Bar Message Books, Multicolor   84.00        5
# 51282                              Avery Binder, Economy   58.05        5
# 51283                     Eaton Parchment Paper, Premium   26.94        2
# 51284                    SanDisk Message Books, 8.5 x 11   18.64        1
# 51285                      Advantus Thumb Tacks, 12 Pack   65.10        5
# 51286      Eldon Image Series Desk Accessories, Burgundy   16.72        5
# 51287                                         Newell 341    8.56        2
# 51288                            Acco Index Tab, Economy   13.44        2
# 51289            Eaton Computer Printout Paper, 8.5 x 11   61.38        3
#
#       Discount  Profit Shipping.Cost Order.Priority Order.Month  Returned  \
# 0         0.00   62.15        40.770           High          11       NaN
# 1         0.10  288.77       923.630       Critical           2       NaN
# 2         0.10  919.97       915.490         Medium          10       NaN
# 3         0.10   96.54       910.160         Medium           1       NaN
# 4         0.00  311.52       903.040       Critical          11       NaN
# 5         0.10  763.28       897.350       Critical           6       NaN
# 6         0.00  564.84       894.770       Critical          11       NaN
# 7         0.00  996.48       878.380           High           4       NaN
# 8         0.00   54.71        25.270           High          11       NaN
# 9         0.20    5.48        11.130           High           3       NaN
# 10        0.00    4.66         4.290           High           3       NaN
# 11        0.00  647.55       835.570           High           4       NaN
# 12        0.00  151.40       832.410       Critical          12       NaN
# 13        0.00  622.02       810.250       Critical          11       NaN
# 14        0.00   36.08       804.540       Critical           6       NaN
# 15        0.10  186.95       801.660       Critical           7       NaN
# 16        0.20    2.52         1.970            Low           2       NaN
# 17        0.00  979.08       778.320            Low           9       NaN
# 18        0.10   28.40       766.930       Critical           1       NaN
# 19        0.00  818.28       763.380           High          12       NaN
# 20        0.00  276.84       759.470       Critical           8       NaN
# 21        0.00    4.86         1.280           High           3       NaN
# 22        0.00  358.02       752.470       Critical           5       NaN
# 23        0.00  898.40       730.910           High           2       NaN
# 24        0.00  445.52       728.968       Critical           7       NaN
# 25        0.20  526.50       728.389       Critical           9       NaN
# 26        0.00  720.36       725.570       Critical          12       Yes
# 27        0.10  364.24       725.340       Critical           3       NaN
# 28        0.00  121.44        55.200       Critical           4       NaN
# 29        0.00  582.36       704.080       Critical           2       NaN
# ...        ...     ...           ...            ...         ...       ...
# 51260     0.80    1.11         1.010         Medium           6       NaN
# 51261     0.20   51.50        69.660         Medium           7       NaN
# 51262     0.20   16.01        14.750           High           8       NaN
# 51263     0.00    3.28         1.039         Medium          12       NaN
# 51264     0.10    8.86         1.030         Medium          11       NaN
# 51265     0.00  124.78        11.840         Medium           4       NaN
# 51266     0.45   18.83         1.030         Medium           8       NaN
# 51267     0.00   16.59         8.470           High           6       NaN
# 51268     0.00    2.16         1.030         Medium           4       NaN
# 51269     0.00   12.00         1.030         Medium           5       NaN
# 51270     0.00    5.88         1.030         Medium           8       NaN
# 51271     0.00   22.05         7.300         Medium           4       NaN
# 51272     0.00    0.56         1.025         Medium           4       NaN
# 51273     0.00    0.04         1.023           High           9       NaN
# 51274     0.00    3.72         1.023           High           9       NaN
# 51275     0.70   21.17         1.020         Medium           3       NaN
# 51276     0.20    7.38         3.210           High           8       NaN
# 51277     0.60   49.57         1.020         Medium          11       NaN
# 51278     0.00   12.60         1.020         Medium          12       NaN
# 51279     0.70    6.46         1.020           High           9       NaN
# 51280     0.20    5.00         2.010         Medium           7       NaN
# 51281     0.00    9.20         1.019           High           6       NaN
# 51282     0.10   19.95         1.010         Medium           8       NaN
# 51283     0.00    1.86         1.010           High           5       NaN
# 51284     0.00    8.00         1.010         Medium          12       NaN
# 51285     0.00    4.50         1.010         Medium           6       NaN
# 51286     0.20    3.34         1.930           High           5       NaN
# 51287     0.00    2.48         1.580           High           8       NaN
# 51288     0.00    2.40         1.003         Medium           2       NaN
# 51289     0.00    1.80         1.002           High           5       NaN
#
#            Region_y
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26     Eastern Asia
# 27              NaN
# 28              NaN
# 29              NaN
# ...             ...
# 51260           NaN
# 51261           NaN
# 51262           NaN
# 51263           NaN
# 51264           NaN
# 51265           NaN
# 51266           NaN
# 51267           NaN
# 51268           NaN
# 51269           NaN
# 51270           NaN
# 51271           NaN
# 51272           NaN
# 51273           NaN
# 51274           NaN
# 51275           NaN
# 51276           NaN
# 51277           NaN
# 51278           NaN
# 51279           NaN
# 51280           NaN
# 51281           NaN
# 51282           NaN
# 51283           NaN
# 51284           NaN
# 51285           NaN
# 51286           NaN
# 51287           NaN
# 51288           NaN
# 51289           NaN
#
# [51290 rows x 27 columns]
